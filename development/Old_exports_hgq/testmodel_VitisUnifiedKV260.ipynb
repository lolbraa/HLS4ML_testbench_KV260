# %% [markdown]
# To install, ´conda env create -f environment-VitisUnified.yml´, or to update env ´conda env update -f environment-VitisUnified.yml´. Remember to restart kernel.

# %%
# Check available backends for vitisunified
import hls4ml
hls4ml.backends.backend.get_available_backends()
# Out:
# ['vivado',
#  'vivadoaccelerator',
#  'vitis',
#  'vitisunified',
#  'quartus',
#  'catapult',
#  'symbolicexpression',
#  'oneapi',
#  'libero']

# %% [markdown]
# # Example of creating a model and importing into a Vivado-project
# Based on [hls4ml-tutorial part 3](https://github.com/fastmachinelearning/hls4ml-tutorial/blob/main/part3_compression.ipynb) and [Tanawin1701d/vitisUnifiedTutorial](https://github.com/Tanawin1701d/vitisUnifiedTutorial).
#
# To store multiple revisions, the following parameters are used throughout. Make sure to update them if you want to keep multiple revisions.
#
# Make sure to start this from conda environment with Vitis loaded to path.
# ´conda activate hls4ml-kv260-testenv´

# %%
import os
model_to_test = 'testmodel'
model_revision = 2
hls4ml_revision = 'VitisUnifiedKV260_2025.2_from_docker'

base_dir = os.path.abspath(model_to_test)
model_dir = os.path.join(base_dir, str(model_revision))
os.makedirs(model_dir, exist_ok=True)

description = """
# Model Configuration

En simpel model for å teste A til Å med Vitis Unified på KV260.
Oppdatert fork som underlag.
Dummet ned til utrolig lite for å nå innenfor KV260-krav.
Compiling with Vitis/Vivado 2025.2 with updated fork of Vitis Unified with new scripts.
FROM INSIDE DOCKER CONTAINER.

- **Model architecture description**: {model_to_test}
- **Model Revision**: {model_revision}
- **HLS4ML Revision**: {hls4ml_revision}
- **Backend**: Vitis Unified [[https://github.com/fastmachinelearning/hls4ml/pull/1376]]
- **Target Device**: KV260 (xck26-sfvc784-2LV-c)
- **Dataset**: HLS4ML LHC Jets
"""
output_dir = os.path.join(model_dir, f"hls4ml_prj_{hls4ml_revision}")
os.makedirs(output_dir, exist_ok=True)
with open(os.path.join(output_dir, "description.md"), "w", encoding="utf-8") as f:
    f.write(description)

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import os

# %matplotlib inline
seed = 0
np.random.seed(seed)

tf.random.set_seed(seed)
# Out:
# 2026-05-05 14:50:44.593671: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load into path and double check Vivado/Vits versions
os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH'] 
# !vitis --version
# !vitis_hls -version
# !vivado -version
# Out:
# ****** Vitis Development Environment
# ****** Vitis v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:14
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
# /bin/bash: line 1: vitis_hls: command not found
# vivado v2025.2 (64-bit)
# Tool Version Limit: 2025.11
# SW Build 6299465 on Fri Nov 14 12:34:56 MST 2025
# IP Build 6300035 on Fri Nov 14 10:48:45 MST 2025
# SharedData Build 6298862 on Thu Nov 13 04:50:51 MST 2025
# Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
# Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.

# %% [markdown]
# Load dataset and save data. If the data is already saved to disk, load the local cache.

# %%
# Use absolute paths for data files
x_train_val_path = os.path.join(base_dir, "x_train_val.npy")
x_test_path = os.path.join(base_dir, "x_test.npy")
y_train_val_path = os.path.join(base_dir, "y_train_val.npy")
y_test_path = os.path.join(base_dir, "y_test.npy")
classes_path = os.path.join(base_dir, "classes.npy")

if not os.path.exists(x_train_val_path):
    from tensorflow.keras.utils import to_categorical
    from sklearn.datasets import fetch_openml
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import LabelEncoder, StandardScaler
    
    data = fetch_openml('hls4ml_lhc_jets_hlf')
    x, y = data['data'], data['target']

    le = LabelEncoder()
    y = le.fit_transform(y)
    y = to_categorical(y, 5)
    # Change to float32
    x = x.astype(np.float32)
    y = y.astype(np.float32)
    # split
    x_train_val, x_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    scaler = StandardScaler()
    x_train_val = scaler.fit_transform(x_train_val)
    x_test = scaler.transform(x_test)

    np.save(x_train_val_path, x_train_val)
    np.save(x_test_path, x_test)
    np.save(y_train_val_path, y_train_val)
    np.save(y_test_path, y_test)
    np.save(classes_path, le.classes_)
    classes = le.classes_
    print("Saved files")
else:
    x_train_val = np.load(x_train_val_path)
    x_test = np.load(x_test_path)
    y_train_val = np.load(y_train_val_path)
    y_test = np.load(y_test_path)
    classes = np.load(classes_path, allow_pickle=True)

# %%
# Prepare subset of testdata for simulation (running everything takes an unnecessary long time)
simulation_rows = 100
x_test_sim_path = os.path.join(base_dir, "x_test_sim.npy")
y_test_sim_path = os.path.join(base_dir, "y_test_sim.npy")
np.save(x_test_sim_path, x_test[:simulation_rows])
np.save(y_test_sim_path, y_test[:simulation_rows])

# %% [markdown]
# Load existing model, or create and train a new

# %%
load_existing_model = True

keras_model_path = os.path.join(model_dir, f"{model_to_test}_{model_revision}_model.keras")

if load_existing_model:
    from keras.models import load_model
    model = load_model(keras_model_path)
else:
    inputs = keras.Input(shape=(16,), name='linput')
    x = keras.layers.Dense(64, input_shape=(16,), name='fc1', kernel_initializer='lecun_uniform')(inputs)
    #x = keras.layers.Activation(activation='relu', name='relu1')(x)
    #x = keras.layers.Dense(32, name='fc2', kernel_initializer='lecun_uniform')(x)
    #x = keras.layers.Activation(activation='relu', name='relu2')(x)
    #x = keras.layers.Dense(32, name='fc3', kernel_initializer='lecun_uniform')(x)
    x = keras.layers.Activation(activation='relu', name='relu3')(x)
    x = keras.layers.Dense(5, name='output', kernel_initializer='lecun_uniform')(x)
    outputs = keras.layers.Activation(activation='softmax', name='softmax')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    model.compile(optimizer="adam", loss=['categorical_crossentropy'], metrics=['accuracy'])
    model.fit(
        x_train_val,
        y_train_val,
        batch_size=1024,
        epochs=3,
        validation_split=0.25,
        shuffle=True,
    )
    model.save(keras_model_path)

# %%
print(classes)
# Out:
# ['g' 'q' 't' 'w' 'z']

# %%
# Save results for plotting example curve in plots/
y_keras = model.predict(x_test)
from sklearn.metrics import accuracy_score
print("Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))

y_keras_path = os.path.join(base_dir, "y_keras.npy")
np.save(y_keras_path, y_keras)

#plot ROC
from plots import plotting
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_keras, classes)


plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_keras, classes, style_semilogx=False)
# Out:
#    1/5188 ━━━━━━━━━━━━━━━━━━━━ 1:16 15ms/step
# 5188/5188 ━━━━━━━━━━━━━━━━━━━━ 2s 338us/step
# Accuracy: 0.7321746987951807

# %%
# Save the model summary to a text file
with open(os.path.join(model_dir, "summary.txt"), "w", encoding="utf-8") as f:
    model.summary(print_fn=lambda line: f.write(line + "\n"))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from plots import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

y_keras = model.predict(X_test)
print("Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 import matplotlib.pyplot as plt
#       3 from sklearn.metrics import accuracy_score
# ----> 5 y_keras = model.predict(X_test)
#       6 print("Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
#       7 plt.figure(figsize=(9, 9))
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# # Convert and synthesize with HLS4ML
# Uses KV260 (xck26-sfvc784-2LV-c).

# %%
import hls4ml
hls_model = hls4ml.converters.convert_from_keras_model(
    model, 
    backend     = 'vitisunified', 
    #project_name=f'{model_to_test}_{model_revision}_hls4ml_prj_{hls4ml_revision}', # Bug ved feil bruk av denne når axi_master.cpp skal hentes i `vitis_unified_writer`
    output_dir  = output_dir, 
    board       = 'kv260',
    part        = 'xck26-sfvc784-2LV-c', # default fra supported-boards.json fungerer ikke i Vivado 2025.2
    clock_period= '5ns',
    # Set input data for model simulation
    input_data_tb= x_test_sim_path,
    output_data_tb=y_test_sim_path,
    #in_stream_buf_size = 256,
    #out_stream_buf_size = 128,
    #input_type  = "double",
    #output_type = "double",
    #xpfmPath    = XPFM_PATH,
    #io_type     = "io_stream",
    #strategy    = "latency",
    #granularity = "name",
    #amt_query   = 10,
    #axi_mode    = "axi_master",
)
hls_model.compile()
#hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True,to_file=os.path.join(output_dir, "model-plot.png"))

# %%
print(hls_model.config.config)
hls_model.config.get_output_dir()
hls_model.config.backend.writer.get_vitis_linker_dir(hls_model)
# Out:
# {'OutputDir': '/home/ncgadmin/Bachelor/HLS4ML_testbench_KV260/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker', 'ProjectName': 'myproject', 'Backend': 'VitisUnified', 'Version': '1.0.0', 'Part': 'xck26-sfvc784-2LV-c', 'ClockPeriod': '5ns', 'ClockUncertainty': '12.5%', 'IOType': 'io_stream', 'HLSConfig': {'Model': {'Precision': 'fixed<16,6>', 'ReuseFactor': 1, 'BitExact': None}}, 'WriterConfig': {'Namespace': None, 'WriteWeightsTxt': True, 'WriteTar': False, 'TBOutputStream': 'both', 'WriteEmulationConstants': False}, 'VitisUnifiedConfig': {'Board': 'kv260', 'axi_mode': 'axi_master', 'in_stream_buf_size': 128, 'out_stream_buf_size': 128, 'Driver': 'python', 'InputDtype': 'float', 'OutputDtype': 'float'}, 'KerasModel': <Functional name=functional, built=True>, 'InputData': '/home/ncgadmin/Bachelor/HLS4ML_testbench_KV260/development/testmodel/x_test_sim.npy', 'OutputPredictions': '/home/ncgadmin/Bachelor/HLS4ML_testbench_KV260/development/testmodel/y_test_sim.npy', 'InputShapes': {'linput': [16]}, 'OutputShapes': {'layer5_out': [5]}, 'Stamp': '74f8c17e'}
# '/home/ncgadmin/Bachelor/HLS4ML_testbench_KV260/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link'

# %% [markdown]
# Test the HLS-model if it actually works

# %%
hls_model.predict(np.ascontiguousarray(x_test[:10]))
# Out:
# array([[5.00000000e-01, 4.27734375e-01, 4.10156250e-02, 4.88281250e-02,
#         1.04492188e-01],
#        [7.42187500e-02, 6.66992188e-01, 5.85937500e-03, 2.30468750e-01,
#         1.30859375e-01],
#        [1.89453125e-01, 7.12890625e-02, 7.99804688e-01, 0.00000000e+00,
#         0.00000000e+00],
#        [1.26953125e-02, 6.83593750e-03, 1.00000000e+00, 7.91015625e-02,
#         0.00000000e+00],
#        [3.71093750e-02, 3.12500000e-02, 1.00000000e+00, 9.76562500e-04,
#         0.00000000e+00],
#        [5.17578125e-02, 1.37695312e-01, 4.00390625e-01, 1.33789062e-01,
#         3.11523438e-01],
#        [4.44335938e-01, 2.86132812e-01, 1.12304688e-01, 9.57031250e-02,
#         6.15234375e-02],
#        [6.66992188e-01, 1.19140625e-01, 4.39453125e-02, 1.01562500e-01,
#         8.39843750e-02],
#        [6.54296875e-02, 5.71289062e-01, 2.05078125e-02, 2.45117188e-01,
#         1.90429688e-01],
#        [1.95312500e-03, 8.78906250e-03, 1.75781250e-02, 1.00000000e+00,
#         1.90429688e-01]], dtype=float32)

# %%
from hls4ml.model.profiling import numerical
plots = numerical(model=model, hls_model=hls_model, X=x_test)
# Out:
# Profiling weights (before optimization)
# [{'med': np.float32(0.2325281), 'q1': np.float32(0.10792297), 'q3': np.float32(0.362161), 'whislo': np.float32(0.00024593418), 'whishi': np.float32(1.3430536), 'layer': 'fc1', 'weight': 'fc1/w'}, {'med': np.float32(0.13749382), 'q1': np.float32(0.058247693), 'q3': np.float32(0.273524), 'whislo': np.float32(0.004193655), 'whishi': np.float32(0.65955603), 'layer': 'fc1', 'weight': 'fc1/b'}, {'med': np.float32(0.1688357), 'q1': np.float32(0.08528304), 'q3': np.float32(0.28213432), 'whislo': np.float32(0.00088249764), 'whishi': np.float32(0.9921037), 'layer': 'output', 'weight': 'output/w'}, {'med': np.float32(0.15400493), 'q1': np.float32(0.1455771), 'q3': np.float32(0.19155867), 'whislo': np.float32(0.12999606), 'whishi': np.float32(0.36057743), 'layer': 'output', 'weight': 'output/b'}]
# Profiling weights (final / after optimization)
# Profiling activations (before optimization)
# 5188/5188 ━━━━━━━━━━━━━━━━━━━━ 2s 399us/step
#    fc1
#    relu3
#    output
#    softmax
# Profiling activations (final / after optimization)
# Recompiling myproject with tracing
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 2
#       1 from hls4ml.model.profiling import numerical
# ----> 2 plots = numerical(model=model, hls_model=hls_model, X=x_test)
#
# File ~/miniconda3/envs/devenv-vu/lib/python3.12/site-packages/hls4ml/model/profiling.py:546, in numerical(model, hls_model, X, plot)
#     544 if hls_model_present:
#     545     print('Profiling activations' + after)
# --> 546     data = activations_hlsmodel(hls_model, X, fmt='summary', plot=plot)
#     547     aph = plots[plot](data, fmt='summary')
#     549     t_data = activation_types_hlsmodel(hls_model)
#
# File ~/miniconda3/envs/devenv-vu/lib/python3.12/site-packages/hls4ml/model/profiling.py:333, in activations_hlsmodel(model, X, fmt, plot)
#     330 _, trace = model.trace(np.ascontiguousarray(X))
#     332 if len(trace) == 0:
# --> 333     raise RuntimeError('ModelGraph must have tracing on for at least 1 layer (this can be set in its config)')
#     335 for layer in trace.keys():
#     336     print(f'   {layer}')
#
# RuntimeError: ModelGraph must have tracing on for at least 1 layer (this can be set in its config)

# %% [markdown]
# # Simulation
# [vitis unified tutorial](https://github.com/Tanawin1701d/vitis_unified_backend_tutorial/blob/master/03_co_simulation.ipynb)

# %%
# Build and do co-simulation
hls_model.build(
    synth=True, # Only needs to run first time
    cosim=True,
    ) 

# Problem 1 19.03.2026
# Version missmatch mellom system glibc og Vitis 2023.2 (binutils)
# Kjøre i Ubuntu 22 docker, se over
# Out:
# ****** v++ v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:13
#   **** Start of session at: Wed Apr 29 10:15:35 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
#   **** HLS Build v2025.2 6295257
# INFO: [HLS 200-2005] Using work_dir /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project
# INFO: [HLS 200-2176] Writing Vitis IDE component file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/vitis-comp.json
# INFO: [HLS 200-10] Creating and opening component '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-2174] Applying component config ini file ../../hls_kernel_config.cfg
# INFO: [HLS 200-1465] Applying config ini 'syn.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' from ../../hls_kernel_config.cfg(7)
# INFO: [HLS 200-10] Adding design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'syn.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' from ../../hls_kernel_config.cfg(8)
# INFO: [HLS 200-10] Adding design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'syn.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp,-std=c++0x' from ../../hls_kernel_config.cfg(9)
# INFO: [HLS 200-1465] Applying config ini 'syn.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp,-std=c++0x' from ../../hls_kernel_config.cfg(10)
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp' from ../../hls_kernel_config.cfg(14)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/weights' from ../../hls_kernel_config.cfg(15)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/weights' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/tb_data' from ../../hls_kernel_config.cfg(16)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/tb_data' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp,-DRTL_SIM' from ../../hls_kernel_config.cfg(18)
# INFO: [HLS 200-1465] Applying config ini 'syn.top=myproject_axi_master' from ../../hls_kernel_config.cfg(12)
# INFO: [HLS 200-1465] Applying config ini 'flow_target=vivado' from ../../hls_kernel_config.cfg(6)
# INFO: [HLS 200-1505] Using flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1465] Applying config ini 'part=xck26-sfvc784-2LV-c' from ../../hls_kernel_config.cfg(1)
# INFO: [HLS 200-1611] Setting target device to 'xck26-sfvc784-2LV-c'
# INFO: [HLS 200-1465] Applying config ini 'clock=5ns' from ../../hls_kernel_config.cfg(4)
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1465] Applying config ini 'clock_uncertainty=12.5%' from ../../hls_kernel_config.cfg(5)
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# INFO: [HLS 200-1465] Applying config ini 'cosim.enable_fifo_sizing=true' from ../../hls_kernel_config.cfg(24)
# INFO: [HLS 200-1465] Applying config ini 'package.ip.version=1.0.0' from ../../hls_kernel_config.cfg(19)
# INFO: [HLS 200-1465] Applying config ini 'package.output.format=xo' from ../../hls_kernel_config.cfg(20)
# INFO: [HLS 200-1465] Applying config ini 'syn.compile.name_max_length=80' from ../../hls_kernel_config.cfg(21)
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1465] Applying config ini 'syn.schedule.enable_dsp_full_reg=0' from ../../hls_kernel_config.cfg(22)
# INFO: [HLS 200-2176] Writing Vitis IDE component file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/vitis-comp.json
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 1.58 seconds. CPU system time: 0.33 seconds. Elapsed time: 1.85 seconds; current allocated memory: 259.145 MB.
# INFO: [HLS 200-2191] C-Synthesis will use clang-16 as the compiler
# INFO: [HLS 200-10] Analyzing design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' ...
# WARNING: [HLS 207-7036] unexpected pragma argument 'softmax', expects function/operation (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_activation.h:402:36)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:33:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:107:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:189:13)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:41:65)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:41:69)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:45:70)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:45:74)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 4 issue(s) in file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-4982] variable templates are a C++14 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:38:23)
# WARNING: [HLS 207-4982] variable templates are a C++14 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:54:23)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:219:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:220:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:221:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:222:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:223:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:224:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:238:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:239:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:240:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:241:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:242:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:243:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:244:8)
# WARNING: [HLS 207-6591] unused parameter 'keep' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_helpers.h:329:99)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-6591] unused parameter 'partition' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-6591] unused parameter 'partition' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-10] Analyzing design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' ...
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 6.83 seconds. CPU system time: 0.57 seconds. Elapsed time: 7.4 seconds; current allocated memory: 266.043 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 6,799 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 83,652 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 27,507 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 27,038 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 25,909 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 10,881 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 7,027 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 7,033 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,759 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,771 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,533 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 9,222 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 9,081 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,977 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,610 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,717 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:85:1)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' (firmware/nnet_utils/nnet_dense_stream.h:85:1)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)', Pragma conflict happens on 'INLINE' and 'FUNCTION_INSTANTIATE' pragmas: same function (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)', Pragma conflict happens on 'INLINE' and 'FUNCTION_INSTANTIATE' pragmas: same function (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*) (.4)', pragma conflict between INLINE (<UNKNOWN LOCATION>) and PIPELINE (firmware/nnet_utils/nnet_dense_stream.h:16:1) because 'PIPELINE + INLINE' is allowed only when inlining a pipeline region into an outer pipeline region (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*) (.11)', pragma conflict between INLINE (<UNKNOWN LOCATION>) and PIPELINE (firmware/nnet_utils/nnet_dense_stream.h:16:1) because 'PIPELINE + INLINE' is allowed only when inlining a pipeline region into an outer pipeline region (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.13)' into 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.12)' (firmware/nnet_utils/nnet_dense_stream.h:47:28)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long) (.6)' into 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&) (.9)' (firmware/nnet_utils/nnet_dense_stream.h:75:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.12)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&) (.9)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*) (.11)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:95:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long) (.6)' into 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*) (.5)' (firmware/nnet_utils/nnet_dense_stream.h:47:28)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[](unsigned long) (.3)' into 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&) (.1)' (firmware/nnet_utils/nnet_dense_stream.h:75:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*) (.5)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&) (.1)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*) (.4)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:95:9)
# INFO: [HLS 214-291] Loop 'SoftmaxArrayPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:200:9)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_211_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:211:27)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_220_2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:220:27)
# INFO: [HLS 214-291] Loop 'SoftmaxInvPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:238:9)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'ReLUPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:49:9)
# INFO: [HLS 214-186] Unrolling loop 'SoftmaxArrayPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:200:9) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_211_1' (firmware/nnet_utils/nnet_activation_stream.h:211:27) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_220_2' (firmware/nnet_utils/nnet_activation_stream.h:220:27) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'SoftmaxInvPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:238:9) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:45:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49:9) in function 'nnet::relu<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, relu_config3>' completely with a factor of 64 (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:45:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void load_input<float, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> >(float*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, int, int)' (firmware/myproject_axi_master.cpp:10:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, relu_config3>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(config4::accum_t)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.75)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# ...
#           lock_queue                  array                                   0     -
#           num_last_reqs               integral                                32    'd1
#           num_last_rsps               integral                                32    'd1
#       state                           axi_state                               -     @3354
#         ar2r_imp                      uvm_analysis_imp_ar2r                   -     @3423
#         ar_imp                        uvm_analysis_imp_ar                     -     @3393
#         aw2b_imp                      uvm_analysis_imp_aw2b                   -     @3413
#         aw_imp                        uvm_analysis_imp_aw                     -     @3363
#         b_imp                         uvm_analysis_imp_b                      -     @3383
#         item_rtr_port                 uvm_analysis_port                       -     @3443
#         item_wtr_port                 uvm_analysis_port                       -     @3433
#         r_imp                         uvm_analysis_imp_r                      -     @3403
#         w_imp                         uvm_analysis_imp_w                      -     @3373
#         avg_rate                      integral                                32    'h0
#         exp_rate                      integral                                32    'h0
#         win_size                      integral                                32    'h0
#         bqnum_for_slaseq              integral                                32    'h0
#         rq_from_model_num             integral                                32    'h0
#       vsqr                            axi_virtual_sequencer                   -     @3462
#         rsp_export                    uvm_analysis_export                     -     @3471
#         seq_item_export               uvm_seq_item_pull_imp                   -     @3589
#         arbitration_queue             array                                   0     -
#         lock_queue                    array                                   0     -
#         num_last_reqs                 integral                                32    'd1
#         num_last_rsps                 integral                                32    'd1
#       cfg                             axi_cfg                                 -     @396
#         has_checker                   integral                                1     'h1
#         has_coverage                  integral                                1     'h1
#         id_num                        integral                                32    'h1
#         reset_level                   reset_level_enum                        32    RESET_LEVEL_LOW
#         drv_type                      drv_type_enum                           32    SLAVE
#         write_latency_mode            latency_mode_enum                       32    TRANSACTION_FIRST
#         read_latency_mode             latency_mode_enum                       32    TRANSACTION_FIRST
#         clatency                      axi_latency                             -     @432
#           wr_latency                  integral                                32    'h0
#           rd_latency                  integral                                32    'h0
#     myproject_axi_master_virtual_sqr  myproject_axi_master_virtual_sequencer  -     @576
#       rsp_export                      uvm_analysis_export                     -     @585
#       seq_item_export                 uvm_seq_item_pull_imp                   -     @703
#       arbitration_queue               array                                   0     -
#       lock_queue                      array                                   0     -
#       num_last_reqs                   integral                                32    'd1
#       num_last_rsps                   integral                                32    'd1
#     refm                              myproject_axi_master_reference_model    -     @494
#       trans_num_idx                   integral                                32    'h0
#     subsys_mon                        myproject_axi_master_subsystem_monitor  -     @507
#       control_rtr_imp                 uvm_analysis_imp_axi_rtr_control        -     @566
#       control_wtr_imp                 uvm_analysis_imp_axi_wtr_control        -     @556
#       gmem_in0_rtr_imp                uvm_analysis_imp_axi_rtr_gmem_in0       -     @526
#       gmem_in0_wtr_imp                uvm_analysis_imp_axi_wtr_gmem_in0       -     @516
#       gmem_out0_rtr_imp               uvm_analysis_imp_axi_rtr_gmem_out0      -     @546
#       gmem_out0_wtr_imp               uvm_analysis_imp_axi_wtr_gmem_out0      -     @536
#       scbd                            myproject_axi_master_scoreboard         -     @4559
#         refm                          myproject_axi_master_reference_model    -     @494
#           trans_num_idx               integral                                32    'h0
#     refm                              myproject_axi_master_reference_model    -     @494
#     myproject_axi_master_virtual_sqr  myproject_axi_master_virtual_sequencer  -     @576
#     myproject_axi_master_cfg          myproject_axi_master_config             -     @394
#       gmem_in0_cfg                    axi_cfg                                 -     @395
#         has_checker                   integral                                1     'h1
#         has_coverage                  integral                                1     'h1
#         id_num                        integral                                32    'h1
#         reset_level                   reset_level_enum                        32    RESET_LEVEL_LOW
#         drv_type                      drv_type_enum                           32    SLAVE
#         write_latency_mode            latency_mode_enum                       32    TRANSACTION_FIRST
#         read_latency_mode             latency_mode_enum                       32    TRANSACTION_FIRST
#         clatency                      axi_latency                             -     @398
#           wr_latency                  integral                                32    'h0
#           rd_latency                  integral                                32    'h0
#       gmem_out0_cfg                   axi_cfg                                 -     @396
#         has_checker                   integral                                1     'h1
#         has_coverage                  integral                                1     'h1
#         id_num                        integral                                32    'h1
#         reset_level                   reset_level_enum                        32    RESET_LEVEL_LOW
#         drv_type                      drv_type_enum                           32    SLAVE
#         write_latency_mode            latency_mode_enum                       32    TRANSACTION_FIRST
#         read_latency_mode             latency_mode_enum                       32    TRANSACTION_FIRST
#         clatency                      axi_latency                             -     @432
#           wr_latency                  integral                                32    'h0
#           rd_latency                  integral                                32    'h0
#       control_cfg                     axi_cfg                                 -     @397
#         has_checker                   integral                                1     'h1
#         has_coverage                  integral                                1     'h1
#         id_num                        integral                                32    'h1
#         reset_level                   reset_level_enum                        32    RESET_LEVEL_LOW
#         drv_type                      drv_type_enum                           32    MASTER
#         write_latency_mode            latency_mode_enum                       32    CHANNEL_FIRST
#         read_latency_mode             latency_mode_enum                       32    CHANNEL_FIRST
#         clatency                      axi_latency                             -     @463
#           wr_latency                  integral                                32    'h0
#           rd_latency                  integral                                32    'h0
#       check_ena                       integral                                32    'h0
#       cover_ena                       integral                                32    'h0
# -----------------------------------------------------------------------------------------------------
#
# UVM_INFO /opt/Xilinx/2025.2/Vivado/data/system_verilog/uvm_1.2/xlnx_uvm_package.sv(20867) @ 0: reporter [UVM/COMP/NAMECHECK] This implementation of the component name checks requires DPI to be enabled
# ////////////////////////////////////////////////////////////////////////////////////
# // Inter-Transaction Progress: Completed Transaction / Total Transaction
# // Intra-Transaction Progress: Measured Latency / Latency Estimation * 100%
# //
# // RTL Simulation : "Inter-Transaction Progress" ["Intra-Transaction Progress"] @ "Simulation Time"
# ////////////////////////////////////////////////////////////////////////////////////
# // RTL Simulation : 0 / 100 [n/a] @ "113000"
# // RTL Simulation : 1 / 100 [n/a] @ "553000"
# // RTL Simulation : 2 / 100 [n/a] @ "943000"
# // RTL Simulation : 3 / 100 [n/a] @ "1333000"
# // RTL Simulation : 4 / 100 [n/a] @ "1723000"
# // RTL Simulation : 5 / 100 [n/a] @ "2113000"
# // RTL Simulation : 6 / 100 [n/a] @ "2503000"
# // RTL Simulation : 7 / 100 [n/a] @ "2893000"
# // RTL Simulation : 8 / 100 [n/a] @ "3283000"
# // RTL Simulation : 9 / 100 [n/a] @ "3673000"
# // RTL Simulation : 10 / 100 [n/a] @ "4063000"
# // RTL Simulation : 11 / 100 [n/a] @ "4453000"
# // RTL Simulation : 12 / 100 [n/a] @ "4843000"
# // RTL Simulation : 13 / 100 [n/a] @ "5233000"
# // RTL Simulation : 14 / 100 [n/a] @ "5623000"
# // RTL Simulation : 15 / 100 [n/a] @ "6013000"
# // RTL Simulation : 16 / 100 [n/a] @ "6403000"
# // RTL Simulation : 17 / 100 [n/a] @ "6793000"
# // RTL Simulation : 18 / 100 [n/a] @ "7183000"
# // RTL Simulation : 19 / 100 [n/a] @ "7573000"
# // RTL Simulation : 20 / 100 [n/a] @ "7963000"
# // RTL Simulation : 21 / 100 [n/a] @ "8353000"
# // RTL Simulation : 22 / 100 [n/a] @ "8743000"
# // RTL Simulation : 23 / 100 [n/a] @ "9133000"
# // RTL Simulation : 24 / 100 [n/a] @ "9523000"
# // RTL Simulation : 25 / 100 [n/a] @ "9913000"
# // RTL Simulation : 26 / 100 [n/a] @ "10303000"
# // RTL Simulation : 27 / 100 [n/a] @ "10693000"
# // RTL Simulation : 28 / 100 [n/a] @ "11083000"
# // RTL Simulation : 29 / 100 [n/a] @ "11473000"
# // RTL Simulation : 30 / 100 [n/a] @ "11863000"
# // RTL Simulation : 31 / 100 [n/a] @ "12253000"
# // RTL Simulation : 32 / 100 [n/a] @ "12643000"
# // RTL Simulation : 33 / 100 [n/a] @ "13033000"
# // RTL Simulation : 34 / 100 [n/a] @ "13423000"
# // RTL Simulation : 35 / 100 [n/a] @ "13813000"
# // RTL Simulation : 36 / 100 [n/a] @ "14203000"
# // RTL Simulation : 37 / 100 [n/a] @ "14593000"
# // RTL Simulation : 38 / 100 [n/a] @ "14983000"
# // RTL Simulation : 39 / 100 [n/a] @ "15373000"
# // RTL Simulation : 40 / 100 [n/a] @ "15763000"
# // RTL Simulation : 41 / 100 [n/a] @ "16153000"
# // RTL Simulation : 42 / 100 [n/a] @ "16543000"
# // RTL Simulation : 43 / 100 [n/a] @ "16933000"
# // RTL Simulation : 44 / 100 [n/a] @ "17323000"
# // RTL Simulation : 45 / 100 [n/a] @ "17713000"
# // RTL Simulation : 46 / 100 [n/a] @ "18103000"
# // RTL Simulation : 47 / 100 [n/a] @ "18493000"
# // RTL Simulation : 48 / 100 [n/a] @ "18883000"
# // RTL Simulation : 49 / 100 [n/a] @ "19273000"
# // RTL Simulation : 50 / 100 [n/a] @ "19663000"
# // RTL Simulation : 51 / 100 [n/a] @ "20053000"
# // RTL Simulation : 52 / 100 [n/a] @ "20443000"
# // RTL Simulation : 53 / 100 [n/a] @ "20833000"
# // RTL Simulation : 54 / 100 [n/a] @ "21223000"
# // RTL Simulation : 55 / 100 [n/a] @ "21613000"
# // RTL Simulation : 56 / 100 [n/a] @ "22003000"
# // RTL Simulation : 57 / 100 [n/a] @ "22393000"
# // RTL Simulation : 58 / 100 [n/a] @ "22783000"
# // RTL Simulation : 59 / 100 [n/a] @ "23173000"
# // RTL Simulation : 60 / 100 [n/a] @ "23563000"
# // RTL Simulation : 61 / 100 [n/a] @ "23953000"
# // RTL Simulation : 62 / 100 [n/a] @ "24343000"
# // RTL Simulation : 63 / 100 [n/a] @ "24733000"
# // RTL Simulation : 64 / 100 [n/a] @ "25123000"
# // RTL Simulation : 65 / 100 [n/a] @ "25513000"
# // RTL Simulation : 66 / 100 [n/a] @ "25903000"
# // RTL Simulation : 67 / 100 [n/a] @ "26293000"
# // RTL Simulation : 68 / 100 [n/a] @ "26683000"
# // RTL Simulation : 69 / 100 [n/a] @ "27073000"
# // RTL Simulation : 70 / 100 [n/a] @ "27463000"
# // RTL Simulation : 71 / 100 [n/a] @ "27853000"
# // RTL Simulation : 72 / 100 [n/a] @ "28243000"
# // RTL Simulation : 73 / 100 [n/a] @ "28633000"
# // RTL Simulation : 74 / 100 [n/a] @ "29023000"
# // RTL Simulation : 75 / 100 [n/a] @ "29413000"
# // RTL Simulation : 76 / 100 [n/a] @ "29803000"
# // RTL Simulation : 77 / 100 [n/a] @ "30193000"
# // RTL Simulation : 78 / 100 [n/a] @ "30583000"
# // RTL Simulation : 79 / 100 [n/a] @ "30973000"
# // RTL Simulation : 80 / 100 [n/a] @ "31363000"
# // RTL Simulation : 81 / 100 [n/a] @ "31753000"
# // RTL Simulation : 82 / 100 [n/a] @ "32143000"
# // RTL Simulation : 83 / 100 [n/a] @ "32533000"
# // RTL Simulation : 84 / 100 [n/a] @ "32923000"
# // RTL Simulation : 85 / 100 [n/a] @ "33313000"
# // RTL Simulation : 86 / 100 [n/a] @ "33703000"
# // RTL Simulation : 87 / 100 [n/a] @ "34093000"
# // RTL Simulation : 88 / 100 [n/a] @ "34483000"
# // RTL Simulation : 89 / 100 [n/a] @ "34873000"
# // RTL Simulation : 90 / 100 [n/a] @ "35263000"
# // RTL Simulation : 91 / 100 [n/a] @ "35653000"
# // RTL Simulation : 92 / 100 [n/a] @ "36043000"
# // RTL Simulation : 93 / 100 [n/a] @ "36433000"
# // RTL Simulation : 94 / 100 [n/a] @ "36823000"
# // RTL Simulation : 95 / 100 [n/a] @ "37213000"
# // RTL Simulation : 96 / 100 [n/a] @ "37603000"
# // RTL Simulation : 97 / 100 [n/a] @ "37993000"
# // RTL Simulation : 98 / 100 [n/a] @ "38383000"
# // RTL Simulation : 99 / 100 [n/a] @ "38773000"
# // RTL Simulation : 100 / 100 [n/a] @ "39163000"
# ////////////////////////////////////////////////////////////////////////////////////
# $finish called at time : 39197500 ps : File "/opt/Xilinx/2025.2/Vivado/data/system_verilog/uvm_1.2/xlnx_uvm_package.sv" Line 18699
# ## quit
# INFO: xsimkernel Simulation Memory Usage: 426032 KB (Peak: 483372 KB), Simulation CPU Usage: 1380 ms
# INFO: [Common 17-206] Exiting xsim at Wed Apr 29 10:17:23 2026...
# INFO: [COSIM 212-316] Starting C post checking ...
# Processing input 0
# Predictions
# 0 1 0 0 0
# Quantized predictions
# 0.5 0.427734 0.0410156 0.0488281 0.104492
# INFO: Saved inference results to file: tb_data/rtl_cosim_results.log
# INFO: [COSIM 212-1000] *** C/RTL co-simulation finished: PASS ***
# INFO: [HLS 200-112] Total CPU user time: 166.63 seconds. Total CPU system time: 4.47 seconds. Total elapsed time: 52.96 seconds; peak allocated memory: 336.133 MB.
# INFO: [vitis-run 60-791] Total elapsed time: 0h 0m 56s

# %%
y_baseline = hls_model.predict(np.ascontiguousarray(x_test[:simulation_rows]))
#y_baseline = model.predict(np.ascontiguousarray(x_test[:simulation_rows]))
y_simulation = np.loadtxt(os.path.join(output_dir, "tb_data/rtl_cosim_results.log"))

# %%
print(f"y_baseline shape: {y_baseline.shape} and y_simulation: {y_simulation.shape}")
#print(y_simulation)
# Out:
# y_baseline shape: (100, 5) and y_simulation: (100, 5)

# %%
assert np.allclose(y_baseline, y_simulation, rtol=0.0, atol=1e-4), (
    "The results from bridge and cosim are NOT equal!"
)
print("\n✅ RTL co-simulation comparison passed, absolute difference is less than 1e-4 (atol=1e-4).")
# Out:
# ✅ RTL co-simulation comparison passed, absolute difference is less than 1e-4 (atol=1e-4).

# %%
from sklearn.metrics import accuracy_score
print("Difference in inference-calculations between HLS4ML bridge and simulated inference (first rows):")
abs_diff = y_baseline[:3] - y_simulation[:3]
print(np.round(abs_diff, 8))

mse = np.mean(np.square(y_baseline - y_simulation))
print(f"MSE: {mse}")


print("Baseline  Accuracy: {}".format(accuracy_score(np.argmax(y_test[:simulation_rows], axis=1), np.argmax(y_baseline, axis=1))))
print("Simulation Accuracy: {}".format(accuracy_score(np.argmax(y_test[:simulation_rows], axis=1), np.argmax(y_simulation, axis=1))))
# Out:
# Difference in inference-calculations between HLS4ML bridge and simulated inference (first rows):
# [[ 0.0e+00  3.7e-07  3.0e-08  3.0e-08  1.9e-07]
#  [-5.0e-08  1.9e-07 -0.0e+00 -2.5e-07  3.7e-07]
#  [ 1.2e-07 -4.0e-08 -3.1e-07  0.0e+00  0.0e+00]]
# MSE: 2.8122890998877146e-14
# Baseline  Accuracy: 0.75
# Simulation Accuracy: 0.75

# %% [markdown]
# # Generate bitfile

# %% [markdown]
# Implementation details
# ![image.png](attachment:image.png)
# [Origin and more information](https://github.com/fastmachinelearning/hls4ml/pull/1376)

# %%
# Create complete bitfile (Vitis Unified-backend) or IP-block (Vitis-backend) 
hls_model.build(
    synth=True, 
    #csim=True,
    bitfile=True
    )
# Out:
# ****** v++ v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:13
#   **** Start of session at: Wed Apr 29 09:54:40 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
#   **** HLS Build v2025.2 6295257
# INFO: [HLS 200-2005] Using work_dir /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project
# INFO: [HLS 200-2176] Writing Vitis IDE component file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/vitis-comp.json
# INFO: [HLS 200-10] Creating and opening component '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-2174] Applying component config ini file ../../hls_kernel_config.cfg
# INFO: [HLS 200-1465] Applying config ini 'syn.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' from ../../hls_kernel_config.cfg(7)
# INFO: [HLS 200-10] Adding design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'syn.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' from ../../hls_kernel_config.cfg(8)
# INFO: [HLS 200-10] Adding design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'syn.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp,-std=c++0x' from ../../hls_kernel_config.cfg(9)
# INFO: [HLS 200-1465] Applying config ini 'syn.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp,-std=c++0x' from ../../hls_kernel_config.cfg(10)
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp' from ../../hls_kernel_config.cfg(14)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/weights' from ../../hls_kernel_config.cfg(15)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/weights' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/tb_data' from ../../hls_kernel_config.cfg(16)
# INFO: [HLS 200-10] Adding test bench file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/tb_data' to the project
# INFO: [HLS 200-1465] Applying config ini 'tb.file_cflags=/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/myproject_test.cpp,-std=c++0x' from ../../hls_kernel_config.cfg(17)
# INFO: [HLS 200-1465] Applying config ini 'syn.top=myproject_axi_master' from ../../hls_kernel_config.cfg(12)
# INFO: [HLS 200-1465] Applying config ini 'flow_target=vivado' from ../../hls_kernel_config.cfg(6)
# INFO: [HLS 200-1505] Using flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1465] Applying config ini 'part=xck26-sfvc784-2LV-c' from ../../hls_kernel_config.cfg(1)
# INFO: [HLS 200-1611] Setting target device to 'xck26-sfvc784-2LV-c'
# INFO: [HLS 200-1465] Applying config ini 'clock=5ns' from ../../hls_kernel_config.cfg(4)
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1465] Applying config ini 'clock_uncertainty=12.5%' from ../../hls_kernel_config.cfg(5)
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# INFO: [HLS 200-1465] Applying config ini 'package.ip.version=1.0.0' from ../../hls_kernel_config.cfg(19)
# INFO: [HLS 200-1465] Applying config ini 'package.output.format=xo' from ../../hls_kernel_config.cfg(20)
# INFO: [HLS 200-1465] Applying config ini 'syn.compile.name_max_length=80' from ../../hls_kernel_config.cfg(21)
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1465] Applying config ini 'syn.schedule.enable_dsp_full_reg=0' from ../../hls_kernel_config.cfg(22)
# INFO: [HLS 200-2176] Writing Vitis IDE component file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/vitis-comp.json
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 1.63 seconds. CPU system time: 0.58 seconds. Elapsed time: 2.52 seconds; current allocated memory: 259.148 MB.
# INFO: [HLS 200-2191] C-Synthesis will use clang-16 as the compiler
# INFO: [HLS 200-10] Analyzing design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp' ...
# WARNING: [HLS 207-7036] unexpected pragma argument 'softmax', expects function/operation (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_activation.h:402:36)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:33:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:107:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_dense_resource.h:189:13)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:41:65)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:41:69)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:45:70)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp:45:74)
# Resolution: For help on HLS 214-113 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 4 issue(s) in file /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-4982] variable templates are a C++14 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:38:23)
# WARNING: [HLS 207-4982] variable templates are a C++14 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:54:23)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:219:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:220:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:221:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:222:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:223:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:224:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:238:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:239:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:240:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:241:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:242:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:243:8)
# WARNING: [HLS 207-1655] constexpr if is a C++17 extension (/opt/Xilinx/2025.2/Vitis/common/technology/autopilot/ap_axi_sdata.h:244:8)
# WARNING: [HLS 207-6591] unused parameter 'keep' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_helpers.h:329:99)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-6591] unused parameter 'partition' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-6591] unused parameter 'partition' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-6591] unused parameter 'data' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-6591] unused parameter 'res' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-6591] unused parameter 'weights' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-6591] unused parameter 'biases' (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-10] Analyzing design file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/firmware/myproject_axi_master.cpp' ...
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 6.89 seconds. CPU system time: 0.6 seconds. Elapsed time: 7.59 seconds; current allocated memory: 266.004 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 6,799 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 83,652 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 27,507 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 27,038 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 25,909 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 10,881 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 7,027 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 7,033 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,759 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,771 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,533 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 9,222 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 9,081 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,977 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,610 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 200-1995] There were 8,717 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details (/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/myproject/vitis_unified_project/hls/syn/report/csynth_design_size.rpt:2)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:85:1)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' (firmware/nnet_utils/nnet_dense_stream.h:85:1)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)', Pragma conflict happens on 'INLINE' and 'FUNCTION_INSTANTIATE' pragmas: same function (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)', Pragma conflict happens on 'INLINE' and 'FUNCTION_INSTANTIATE' pragmas: same function (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*) (.4)', pragma conflict between INLINE (<UNKNOWN LOCATION>) and PIPELINE (firmware/nnet_utils/nnet_dense_stream.h:16:1) because 'PIPELINE + INLINE' is allowed only when inlining a pipeline region into an outer pipeline region (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*) (.11)', pragma conflict between INLINE (<UNKNOWN LOCATION>) and PIPELINE (firmware/nnet_utils/nnet_dense_stream.h:16:1) because 'PIPELINE + INLINE' is allowed only when inlining a pipeline region into an outer pipeline region (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.13)' into 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.12)' (firmware/nnet_utils/nnet_dense_stream.h:47:28)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long) (.6)' into 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&) (.9)' (firmware/nnet_utils/nnet_dense_stream.h:75:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.12)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&) (.9)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*) (.11)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:95:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long) (.6)' into 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*) (.5)' (firmware/nnet_utils/nnet_dense_stream.h:47:28)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[](unsigned long) (.3)' into 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&) (.1)' (firmware/nnet_utils/nnet_dense_stream.h:75:13)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::value_type*) (.5)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::value_type*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&) (.1)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*) (.4)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, 0>&, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:95:9)
# INFO: [HLS 214-291] Loop 'SoftmaxArrayPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:200:9)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_211_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:211:27)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_220_2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:220:27)
# INFO: [HLS 214-291] Loop 'SoftmaxInvPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:238:9)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'ReLUPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:49:9)
# INFO: [HLS 214-186] Unrolling loop 'SoftmaxArrayPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:200:9) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_211_1' (firmware/nnet_utils/nnet_activation_stream.h:211:27) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_220_2' (firmware/nnet_utils/nnet_activation_stream.h:220:27) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'SoftmaxInvPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:238:9) in function 'nnet::softmax_stable<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, softmax_config5>' completely with a factor of 5 (firmware/nnet_utils/nnet_activation_stream.h:169:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:45:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' completely with a factor of 5 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49:9) in function 'nnet::relu<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, relu_config3>' completely with a factor of 64 (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:45:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 64 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void load_input<float, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> >(float*, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, int, int)' (firmware/myproject_axi_master.cpp:10:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, relu_config3>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 64u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(config4::accum_t)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config4::weight_t*, config4::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.75)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.43.52)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 5, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:37:0)
# ...
# INFO: [v++ 60-1454] Run Directory: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/run_link
#
# ****** vpl v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:13
#   **** Start of session at: Wed Apr 29 09:56:18 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
# INFO: [VPL 60-839] Read in kernel information from file '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/kernel_info.dat'.
# INFO: [VPL 60-423]   Target device: vendor_kv260_som_som240_1_connector_kv260_carrier_som240_1_connector_kv260pf_0_0
# INFO: [VPL 60-1032] Extracting hardware platform to /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/vivado/vpl/.local/hw_platform
# [09:56:21] Run vpl: Step create_project: Started
# Creating Vivado project.
# [09:56:23] Run vpl: Step create_project: Completed
# [09:56:23] Run vpl: Step create_bd: Started
# [09:56:26] Run vpl: Step create_bd: Completed
# [09:56:26] Run vpl: Step update_bd: Started
# [09:56:26] Run vpl: Step update_bd: Completed
# [09:56:26] Run vpl: Step generate_target: Started
# [09:56:43] Run vpl: Step generate_target: Completed
# [09:56:43] Run vpl: Step config_hw_runs: Started
# [09:56:45] Run vpl: Step config_hw_runs: Completed
# [09:56:45] Run vpl: Step synth: Started
# [09:57:16] Block-level synthesis in progress, 2 of 10 jobs complete, 6 jobs running.
# [09:57:46] Block-level synthesis in progress, 7 of 10 jobs complete, 3 jobs running.
# [09:58:16] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [09:58:46] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [09:59:16] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [09:59:46] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:00:16] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:00:46] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:01:17] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:01:47] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:02:17] Block-level synthesis in progress, 9 of 10 jobs complete, 1 job running.
# [10:02:47] Top-level synthesis in progress.
# [10:02:59] Run vpl: Step synth: Completed
# [10:02:59] Run vpl: Step impl: Started
# [10:03:59] Finished 2nd of 6 tasks (FPGA linking synthesized kernels to platform). Elapsed time: 00h 07m 40s
#
# [10:03:59] Starting logic optimization..
# [10:03:59] Phase 1 Initialization
# [10:03:59] Phase 1.1 Core Generation And Design Setup
# [10:03:59] Phase 1.2 Setup Constraints And Sort Netlist
# [10:03:59] Phase 2 Timer Update And Timing Data Collection
# [10:03:59] Phase 2.1 Detect if minReqCache needed
# [10:03:59] Phase 2.2 Timer Update
# [10:03:59] Phase 2.3 Timing Data Collection
# [10:03:59] Phase 3 Retarget
# [10:03:59] Phase 4 Constant propagation
# [10:03:59] Phase 5 Sweep
# [10:03:59] Phase 6 BUFG optimization
# [10:03:59] Phase 7 Shift Register Optimization
# [10:03:59] Phase 8 Post Processing Netlist
# [10:03:59] Phase 9 Finalization
# [10:03:59] Phase 9.1 Finalizing Design Cores and Updating Shapes
# [10:04:29] Phase 9.2 Verifying Netlist Connectivity
# [10:04:29] Finished 3rd of 6 tasks (FPGA logic optimization). Elapsed time: 00h 00m 30s
#
# [10:04:29] Starting logic placement..
# [10:04:29] Phase 1 Placer Initialization
# [10:04:29] Phase 1.1 Placer Initialization Netlist Sorting
# [10:04:29] Phase 1.2 IO Placement/ Clock Placement/ Build Placer Device
# [10:04:59] Phase 1.3 Build Placer Netlist Model
# [10:04:59] Phase 1.4 Constrain Clocks/Macros
# [10:04:59] Phase 2 Global Placement
# [10:04:59] Phase 2.1 Floorplanning
# [10:05:29] Phase 2.1.1 Partition Driven Placement
# [10:05:29] Phase 2.1.1.1 PBP: Partition Driven Placement
# [10:05:29] Phase 2.1.1.2 PBP: Clock Region Placement
# [10:05:29] Phase 2.1.1.3 PBP: Discrete Incremental
# [10:05:29] Phase 2.1.1.4 PBP: Compute Congestion
# [10:05:29] Phase 2.1.1.5 PBP: Macro Placement
# [10:05:29] Phase 2.1.1.6 PBP: UpdateTiming
# [10:05:29] Phase 2.1.1.7 PBP: Add part constraints
# [10:05:29] Phase 2.2 Update Timing before SLR Path Opt
# [10:05:29] Phase 2.3 Post-Processing in Floorplanning
# [10:05:29] Phase 2.4 Global Place Phase1
# [10:05:59] Phase 2.5 Global Place Phase2
# [10:05:59] Phase 2.5.1 UpdateTiming Before Physical Synthesis
# [10:05:59] Phase 2.5.2 Physical Synthesis In Placer
# [10:06:29] Phase 3 Detail Placement
# [10:06:29] Phase 3.1 Commit Multi Column Macros
# [10:06:29] Phase 3.2 Commit Most Macros & LUTRAMs
# [10:06:29] Phase 3.3 Small Shape DP
# [10:06:29] Phase 3.3.1 Small Shape Clustering
# [10:06:29] Phase 3.3.2 Slice Area Swap
# [10:06:29] Phase 3.3.2.1 Slice Area Swap Initial
# [10:06:29] Phase 3.4 Re-assign LUT pins
# [10:06:29] Phase 3.5 Pipeline Register Optimization
# [10:06:29] Phase 4 Post Placement Optimization and Clean-Up
# [10:06:29] Phase 4.1 Post Commit Optimization
# [10:07:00] Phase 4.1.1 Post Placement Optimization
# [10:07:00] Phase 4.1.1.1 BUFG Insertion
# [10:07:00] Phase 1 Physical Synthesis Initialization
# [10:07:00] Phase 4.1.1.2 Post Placement Timing Optimization
# [10:07:00] Phase 4.2 Post Placement Cleanup
# [10:07:00] Phase 4.3 Placer Reporting
# [10:07:00] Phase 4.3.1 Print Estimated Congestion
# [10:07:00] Phase 4.4 Final Placement Cleanup
# [10:07:30] Finished 4th of 6 tasks (FPGA logic placement). Elapsed time: 00h 03m 00s
#
# [10:07:30] Starting logic routing..
# [10:07:30] Phase 1 Build RT Design
# [10:07:30] Phase 2 Router Initialization
# [10:07:30] Phase 2.1 Fix Topology Constraints
# [10:07:30] Phase 2.2 Pre Route Cleanup
# [10:07:30] Phase 2.3 Global Clock Net Routing
# [10:07:30] Phase 2.4 Update Timing
# [10:07:30] Phase 2.5 Soft Constraint Pins - Fast Budgeting
# [10:07:30] Phase 3 Global Routing
# [10:07:30] Phase 4 Initial Routing
# [10:07:30] Phase 4.1 Initial Net Routing Pass
# [10:07:30] Phase 5 Rip-up And Reroute
# [10:07:30] Phase 5.1 Global Iteration 0
# [10:10:00] Phase 5.2 Global Iteration 1
# [10:10:00] Phase 6 Delay and Skew Optimization
# [10:10:00] Phase 6.1 Delay CleanUp
# [10:10:00] Phase 6.2 Clock Skew Optimization
# [10:10:00] Phase 7 Post Hold Fix
# [10:10:00] Phase 7.1 Hold Fix Iter
# [10:10:00] Phase 8 Route finalize
# [10:10:00] Phase 9 Verifying routed nets
# [10:10:00] Phase 10 Depositing Routes
# [10:10:00] Phase 11 Resolve XTalk
# [10:10:00] Phase 12 Post Process Routing
# [10:10:00] Phase 13 Post Router Timing
# [10:10:00] Phase 14 Post-Route Event Processing
# [10:10:00] Finished 5th of 6 tasks (FPGA routing). Elapsed time: 00h 02m 30s
#
# [10:10:00] Starting bitstream generation..
# [10:10:35] Creating bitmap...
# [10:10:35] Writing bitstream ./vitis_design_wrapper.bit...
# [10:10:35] Finished 6th of 6 tasks (FPGA bitstream generation). Elapsed time: 00h 00m 35s
# Check VPL, containing 6 checks, has run: 0 errors
# [10:10:35] Run vpl: Step impl: Completed
# [10:10:35] Run vpl: FINISHED. Run Status: impl Complete!
# INFO: [v++ 60-1441] [10:10:35] Run run_link: Step vpl: Completed
# Time (s): cpu = 00:29:20 ; elapsed = 00:14:18 . Memory (MB): peak = 529.227 ; gain = 0.000 ; free physical = 47076 ; free virtual = 53972
# INFO: [v++ 60-1443] [10:10:35] Run run_link: Step rtdgen: Started
# INFO: [v++ 60-1453] Command Line: rtdgen
# INFO: [v++ 60-1454] Run Directory: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/run_link
# INFO: [v++ 60-1453] Command Line: cf2sw -a /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/address_map.xml -sdsl /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/sdsl.dat -xclbin /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/xclbin_orig.xml -rtd /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject.rtd -o /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject.xml
# INFO: [v++ 60-1652] Cf2sw returned exit code: 0
# INFO: [v++ 60-1441] [10:10:36] Run run_link: Step rtdgen: Completed
# Time (s): cpu = 00:00:00.56 ; elapsed = 00:00:00.59 . Memory (MB): peak = 529.227 ; gain = 0.000 ; free physical = 47036 ; free virtual = 53931
# INFO: [v++ 60-1443] [10:10:36] Run run_link: Step xclbinutil: Started
# INFO: [v++ 60-1453] Command Line: xclbinutil --add-section BITSTREAM:RAW:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/system.bit --force --target hw --key-value SYS:dfx_enable:false --add-section :JSON:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject.rtd --add-section CLOCK_FREQ_TOPOLOGY:JSON:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject_xml.rtd --add-section BUILD_METADATA:JSON:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject_build.rtd --add-section EMBEDDED_METADATA:RAW:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject.xml --add-section SYSTEM_METADATA:RAW:/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/systemDiagramModelSlrBaseAddress.json --key-value SYS:PlatformVBNV:vendor_kv260_som_som240_1_connector_kv260_carrier_som240_1_connector_kv260pf_0_0 --output /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/myproject.xclbin
# INFO: [v++ 60-1454] Run Directory: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/run_link
# XRT Build Version: 2.19.0 (Vitis)
#        Build Date: 2025-02-07 10:52:04
#           Hash ID: f02de266f785111094b02d32a9012bd0da3abd58
# Creating a default 'in-memory' xclbin image.
#
# Section: 'BITSTREAM'(0) was successfully added.
# Size   : 7797832 bytes
# Format : RAW
# File   : '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/system.bit'
#
# Section: 'MEM_TOPOLOGY'(6) was successfully added.
# Format : JSON
# File   : 'mem_topology'
#
# Section: 'IP_LAYOUT'(8) was successfully added.
# Format : JSON
# File   : 'ip_layout'
#
# Section: 'CONNECTIVITY'(7) was successfully added.
# Format : JSON
# File   : 'connectivity'
# WARNING: Skipping CLOCK_FREQ_TOPOLOGY section for count size is zero.
# WARNING: Section 'CLOCK_FREQ_TOPOLOGY' content is empty.  No data in the given JSON file.
#
# Section: 'CLOCK_FREQ_TOPOLOGY'(11) was empty.  No action taken.
# Format : JSON
# File   : '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject_xml.rtd'
#
# Section: 'BUILD_METADATA'(14) was successfully added.
# Size   : 2208 bytes
# Format : JSON
# File   : '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject_build.rtd'
#
# Section: 'EMBEDDED_METADATA'(2) was successfully added.
# Size   : 3000 bytes
# Format : RAW
# File   : '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/myproject.xml'
#
# Section: 'SYSTEM_METADATA'(22) was successfully added.
# Size   : 10737 bytes
# Format : RAW
# File   : '/work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/int/systemDiagramModelSlrBaseAddress.json'
# Successfully wrote (7820830 bytes) to the output file: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/myproject.xclbin
# Leaving xclbinutil.
# INFO: [v++ 60-1441] [10:10:36] Run run_link: Step xclbinutil: Completed
# Time (s): cpu = 00:00:00.03 ; elapsed = 00:00:00.08 . Memory (MB): peak = 529.227 ; gain = 0.000 ; free physical = 47012 ; free virtual = 53917
# INFO: [v++ 60-1443] [10:10:36] Run run_link: Step xclbinutilinfo: Started
# INFO: [v++ 60-1453] Command Line: xclbinutil --quiet --force --info /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/myproject.xclbin.info --input /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/myproject.xclbin
# INFO: [v++ 60-1454] Run Directory: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/link/run_link
# INFO: [v++ 60-1441] [10:10:36] Run run_link: Step xclbinutilinfo: Completed
# Time (s): cpu = 00:00:00.05 ; elapsed = 00:00:00.08 . Memory (MB): peak = 529.227 ; gain = 0.000 ; free physical = 47004 ; free virtual = 53909
# Check POST-VPL, containing 1 checks, has run: 0 errors
# INFO: [v++ 60-2397] Platform default or user specified output type sd_card detected but is not a supported output for v++ --link. Use the v++ --package option instead to create SD card output.
# INFO: [v++ 60-586] Created myproject.xclbin
# INFO: [v++ 60-1307] Run completed. Additional information can be found in:
# 	Guidance: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/reports/link/v++_link_myproject_guidance.html
# 	Timing Report: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/reports/link/imp/impl_1_vitis_design_wrapper_timing_summary_routed.rpt
# 	Vivado Log: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/logs/link/vivado.log
# 	Steps Log File: /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/_x/logs/link/link.steps.log
#
# INFO: [v++ 60-2343] Use the Vitis Unified IDE to visualize and navigate the reports. Run the following command.
#     vitis -a/ --analyze /work/development/testmodel/2/hls4ml_prj_VitisUnifiedKV260_2025.2_from_docker/vitis_workspace/system_link/myproject.xclbin.link_summary
# INFO: [v++ 60-791] Total elapsed time: 0h 14m 24s
# INFO: [v++ 60-1653] Closing dispatch client.
# XRT Build Version: 2.19.0 (Vitis)
#        Build Date: 2025-02-07 10:52:04
#           Hash ID: f02de266f785111094b02d32a9012bd0da3abd58
# ------------------------------------------------------------------------------
# Warning: The option '--output' has not been specified. All operations will
#          be done in memory with the exception of the '--dump-section' command.
# ------------------------------------------------------------------------------
# Reading xclbin file into memory.  File: myproject.xclbin
#
# Section: 'BITSTREAM'(0) was successfully written.
# Format: RAW
# File  : '../../export/system.bit'
# Leaving xclbinutil.

# %%
hls4ml.report.read_vivado_report(output_dir)
hls4ml.report.read_vivado_report(os.path.join(output_dir,"final_reports/"))
hls4ml.report.read_vivado_report(os.path.join(output_dir,"final_reports/"))
# Out:
# Unable to read project data. Exiting.
# Unable to read project data. Exiting.

# %% [markdown]
# # Run inference
# Created a notebook in "onboard-verification" for the devkit. The following is just to print results to test against hw.
